# %%
import numpy as np
import pandas as pd

# %%
cursos = pd.read_csv('Curso_2009-2016.csv')

# %%
cursos
# Out:
#       ORIGEM_INFORMACAO   ANO  CO_IES  \
# 0                 CENSO  2016       1
# 1                 CENSO  2016       1
# 2                 CENSO  2016       1
# 3                 CENSO  2016       1
# 4                 CENSO  2016       1
# 5                 CENSO  2016       1
# 6                 CENSO  2016       1
# 7                 CENSO  2016       1
# 8                 CENSO  2016       1
# 9                 CENSO  2016       1
# 10                CENSO  2016       1
# 11                CENSO  2016       1
# 12                CENSO  2016       1
# 13                CENSO  2016       1
# 14                CENSO  2016       1
# 15                CENSO  2016       1
# 16                CENSO  2016       1
# 17                CENSO  2016       1
# 18                CENSO  2016       1
# 19                CENSO  2016       1
# 20                CENSO  2015       1
# 21                CENSO  2016       1
# 22                CENSO  2016       1
# ...

# %% [markdown]
# # CONSULTAS

# %%
cursos[cursos['NO_CURSO'].str.contains('AREA PROFISSIONAL') & (cursos['GRAU_ACADEMICO']!="TECNOLOGICO") ]
# Out:
# Empty DataFrame
# Columns: [ORIGEM_INFORMACAO, ANO, CO_IES, NO_IES, CO_CURSO, NO_CURSO, CO_OCDE, TP_ATRIBUTO_INGRESSO, ATRIBUTO_INGRESSO, CO_NIVEL_ACADEMICO, NIVEL_ACADEMICO, CO_GRAU_ACADEMICO, GRAU_ACADEMICO, CO_MODALIDADE_ENSINO, MODALIDADE_ENSINO, IN_MATRICULADO_ANO_CENSO, TEVE_ALUNO, CO_SITUACAO_FUNCIONAMENTO, DS_SITUACAO_FUNCIONAMENTO]
# Index: []

# %%
cursos[cursos['NO_CURSO'].str.contains('AREAS PROFISSIONAIS') & (cursos['GRAU_ACADEMICO']!="TECNOLOGICO")  ]
# Out:
# Empty DataFrame
# Columns: [ORIGEM_INFORMACAO, ANO, CO_IES, NO_IES, CO_CURSO, NO_CURSO, CO_OCDE, TP_ATRIBUTO_INGRESSO, ATRIBUTO_INGRESSO, CO_NIVEL_ACADEMICO, NIVEL_ACADEMICO, CO_GRAU_ACADEMICO, GRAU_ACADEMICO, CO_MODALIDADE_ENSINO, MODALIDADE_ENSINO, IN_MATRICULADO_ANO_CENSO, TEVE_ALUNO, CO_SITUACAO_FUNCIONAMENTO, DS_SITUACAO_FUNCIONAMENTO]
# Index: []

# %%
cursos[cursos['NO_CURSO'].str.contains('EIXO TECNOLOGICO') & (cursos['GRAU_ACADEMICO']!="TECNOLOGICO")  ]
# Out:
#       ORIGEM_INFORMACAO   ANO  CO_IES  \
# 37312             CENSO  2009    2964
# 37602             CENSO  2009    1970
#
#                                            NO_IES  CO_CURSO  \
# 37312  FACULDADE DE CIENCIAS DE BRASILIA  FACIBRA    112286
# 37602                 FACULDADE DO ESPIRITO SANTO    113082
#
#                                                 NO_CURSO CO_OCDE  \
# 37312  CURSO SUPERIOR DE TECNOLOGIA EM REDES DE COMPU...  481A01
# 37602  CURSO SUPERIOR DE TECNOLOGIA EM COMERCIO EXTER...  340N02
#
#        TP_ATRIBUTO_INGRESSO ATRIBUTO_INGRESSO  CO_NIVEL_ACADEMICO  \
# 37312                   NaN               NaN                   1
# 37602                   NaN               NaN                   1
#
#       NIVEL_ACADEMICO  CO_GRAU_ACADEMICO GRAU_ACADEMICO  CO_MODALIDADE_ENSINO  \
# 37312       GRADUAÇÃO                1.0    BACHARELADO                     1
# 37602       GRADUAÇÃO                1.0    BACHARELADO                     1
#
# ...

# %%
cursos[cursos['NO_CURSO'].str.contains('EIXOTECNOLOGICO') & (cursos['GRAU_ACADEMICO']!="TECNOLOGICO")  ]
# Out:
# Empty DataFrame
# Columns: [ORIGEM_INFORMACAO, ANO, CO_IES, NO_IES, CO_CURSO, NO_CURSO, CO_OCDE, TP_ATRIBUTO_INGRESSO, ATRIBUTO_INGRESSO, CO_NIVEL_ACADEMICO, NIVEL_ACADEMICO, CO_GRAU_ACADEMICO, GRAU_ACADEMICO, CO_MODALIDADE_ENSINO, MODALIDADE_ENSINO, IN_MATRICULADO_ANO_CENSO, TEVE_ALUNO, CO_SITUACAO_FUNCIONAMENTO, DS_SITUACAO_FUNCIONAMENTO]
# Index: []

# %%
cursos[cursos['NO_CURSO'].str.contains('EIXOTECNOLOGICIO') & (cursos['GRAU_ACADEMICO']!="TECNOLOGICO")  ]
# Out:
# Empty DataFrame
# Columns: [ORIGEM_INFORMACAO, ANO, CO_IES, NO_IES, CO_CURSO, NO_CURSO, CO_OCDE, TP_ATRIBUTO_INGRESSO, ATRIBUTO_INGRESSO, CO_NIVEL_ACADEMICO, NIVEL_ACADEMICO, CO_GRAU_ACADEMICO, GRAU_ACADEMICO, CO_MODALIDADE_ENSINO, MODALIDADE_ENSINO, IN_MATRICULADO_ANO_CENSO, TEVE_ALUNO, CO_SITUACAO_FUNCIONAMENTO, DS_SITUACAO_FUNCIONAMENTO]
# Index: []

# %%
cursos[cursos['NO_CURSO'].str.contains('EAD') & (cursos['MODALIDADE_ENSINO']!="DISTANCIA") ]
# Out:
# Empty DataFrame
# Columns: [ORIGEM_INFORMACAO, ANO, CO_IES, NO_IES, CO_CURSO, NO_CURSO, CO_OCDE, TP_ATRIBUTO_INGRESSO, ATRIBUTO_INGRESSO, CO_NIVEL_ACADEMICO, NIVEL_ACADEMICO, CO_GRAU_ACADEMICO, GRAU_ACADEMICO, CO_MODALIDADE_ENSINO, MODALIDADE_ENSINO, IN_MATRICULADO_ANO_CENSO, TEVE_ALUNO, CO_SITUACAO_FUNCIONAMENTO, DS_SITUACAO_FUNCIONAMENTO]
# Index: []

# %%
cursos[cursos['NO_CURSO'].str.contains('ENSINO DISTANCIA') & (cursos['MODALIDADE_ENSINO']!="DISTANCIA") ]
# Out:
# Empty DataFrame
# Columns: [ORIGEM_INFORMACAO, ANO, CO_IES, NO_IES, CO_CURSO, NO_CURSO, CO_OCDE, TP_ATRIBUTO_INGRESSO, ATRIBUTO_INGRESSO, CO_NIVEL_ACADEMICO, NIVEL_ACADEMICO, CO_GRAU_ACADEMICO, GRAU_ACADEMICO, CO_MODALIDADE_ENSINO, MODALIDADE_ENSINO, IN_MATRICULADO_ANO_CENSO, TEVE_ALUNO, CO_SITUACAO_FUNCIONAMENTO, DS_SITUACAO_FUNCIONAMENTO]
# Index: []

# %%
cursos[cursos['NO_CURSO'].str.contains('SEMIPRESENCIAL') & (cursos['MODALIDADE_ENSINO']!="DISTANCIA") ]
# Out:
# Empty DataFrame
# Columns: [ORIGEM_INFORMACAO, ANO, CO_IES, NO_IES, CO_CURSO, NO_CURSO, CO_OCDE, TP_ATRIBUTO_INGRESSO, ATRIBUTO_INGRESSO, CO_NIVEL_ACADEMICO, NIVEL_ACADEMICO, CO_GRAU_ACADEMICO, GRAU_ACADEMICO, CO_MODALIDADE_ENSINO, MODALIDADE_ENSINO, IN_MATRICULADO_ANO_CENSO, TEVE_ALUNO, CO_SITUACAO_FUNCIONAMENTO, DS_SITUACAO_FUNCIONAMENTO]
# Index: []

# %%
cursos[cursos['NO_CURSO'].str.contains('SUPERIOR TECNOLOGIA') & (cursos['GRAU_ACADEMICO']!="TECNOLOGICO")  ]
# Out:
# Empty DataFrame
# Columns: [ORIGEM_INFORMACAO, ANO, CO_IES, NO_IES, CO_CURSO, NO_CURSO, CO_OCDE, TP_ATRIBUTO_INGRESSO, ATRIBUTO_INGRESSO, CO_NIVEL_ACADEMICO, NIVEL_ACADEMICO, CO_GRAU_ACADEMICO, GRAU_ACADEMICO, CO_MODALIDADE_ENSINO, MODALIDADE_ENSINO, IN_MATRICULADO_ANO_CENSO, TEVE_ALUNO, CO_SITUACAO_FUNCIONAMENTO, DS_SITUACAO_FUNCIONAMENTO]
# Index: []

# %%
cursos[cursos['NO_CURSO'].str.contains('SEQUENCIAL') & (cursos['NIVEL_ACADEMICO']!="SEQUENCIAL")  ]
# Out:
#       ORIGEM_INFORMACAO   ANO  CO_IES                           NO_IES  \
# 37832             CENSO  2009     634  UNIVERSIDADE FEDERAL DE PELOTAS
#
#        CO_CURSO                            NO_CURSO CO_OCDE  \
# 37832    113669  CURSO SEQUENCIAL EM GESTAO PUBLICA  345A10
#
#        TP_ATRIBUTO_INGRESSO ATRIBUTO_INGRESSO  CO_NIVEL_ACADEMICO  \
# 37832                   NaN               NaN                   1
#
#       NIVEL_ACADEMICO  CO_GRAU_ACADEMICO GRAU_ACADEMICO  CO_MODALIDADE_ENSINO  \
# 37832       GRADUAÇÃO                3.0    TECNOLOGICO                     1
#
#       MODALIDADE_ENSINO  IN_MATRICULADO_ANO_CENSO TEVE_ALUNO  \
# 37832        PRESENCIAL                       1.0        SIM
#
#        CO_SITUACAO_FUNCIONAMENTO DS_SITUACAO_FUNCIONAMENTO
# 37832                        NaN                       NaN

# %%
cursos[cursos['NO_CURSO'].str.contains('SEQUNCIAL') & (cursos['NIVEL_ACADEMICO']!="SEQUENCIAL")  ]
# Out:
# Empty DataFrame
# Columns: [ORIGEM_INFORMACAO, ANO, CO_IES, NO_IES, CO_CURSO, NO_CURSO, CO_OCDE, TP_ATRIBUTO_INGRESSO, ATRIBUTO_INGRESSO, CO_NIVEL_ACADEMICO, NIVEL_ACADEMICO, CO_GRAU_ACADEMICO, GRAU_ACADEMICO, CO_MODALIDADE_ENSINO, MODALIDADE_ENSINO, IN_MATRICULADO_ANO_CENSO, TEVE_ALUNO, CO_SITUACAO_FUNCIONAMENTO, DS_SITUACAO_FUNCIONAMENTO]
# Index: []
